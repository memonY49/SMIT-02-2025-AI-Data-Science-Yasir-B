# %%
import seaborn as sns 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(42)
myarr = np.random.normal(loc = 50, scale = 10, size = 10)
myarr
# Out:
# array([54.96714153, 48.61735699, 56.47688538, 65.23029856, 47.65846625,
#        47.65863043, 65.79212816, 57.67434729, 45.30525614, 55.42560044])

# %%
sns.boxplot(myarr)
# Out:
# <Axes: >

# %%
data = [1,4,5,7,3,9,100,5,8,105,5,8,8, -50] 
data = np.array(data)

# %%
data
# Out:
# array([  1,   4,   5,   7,   3,   9, 100,   5,   8, 105,   5,   8,   8,
#        -50])

# %%
q1, q3 = np.percentile(data, [25,75])

# %%
iqr = q3-q1
print(f"Lower Fence: {q1 - (1.5*iqr)}")
print(f"Upper Fence: {q3 + (1.5*iqr)}")
print(data.mean())
# Out:
# Lower Fence: -1.375
# Upper Fence: 13.625
# 18.785714285714285

# %%
plt.figure(figsize=(5,10))
sns.boxplot(data)
# Out:
# <Axes: >

# %%
np.random.seed(42)
data1 = np.random.normal(loc = 50, scale = 10, size = 1000)
mean1 = np.mean(data1)
print(f"mean: {mean1}")
variance = np.var(data1)
print(f"variance: {variance}")
std = np.std(data1)
threshold = 3 # 3rd std
print(f"Std: {std}")
outliers = []
sns.boxplot(data1)
plt.show()
plt.axvline(mean1, color = 'red')
plt.axvline(mean1+std, color = 'g')
plt.axvline(mean1-std, color = 'g')
plt.axvline(mean1+2*std, color = 'b')
plt.axvline(mean1-2*std, color = 'b')
plt.axvline(mean1+3*std, color = 'y')
plt.axvline(mean1-3*std, color = 'y')
# plt.axhline(y = variance/1000, color = 'r',  linestyle = '--',linewidth = 4)
sns.histplot(data1)
# Out:
# mean: 50.193320558223256
# variance: 95.79049897315173
# Std: 9.787262077473542
# <Axes: ylabel='Count'>

# %%
mean1 = np.mean(data)
print(f"mean: {mean1}")
variance = np.var(data)
print(f"variance: {variance}")
std = np.std(data)
threshold = 3 # 3rd std
print(f"Std: {std}")
outliers = []
sns.boxplot(data)
plt.show()
plt.axvline(mean1, color = 'red')
plt.axvline(mean1+std, color = 'g')
plt.axvline(mean1-std, color = 'g')
plt.axvline(mean1+2*std, color = 'b')
plt.axvline(mean1-2*std, color = 'b')
# plt.axvline(mean1+3*std, color = 'y')
# plt.axvline(mean1-3*std, color = 'y')
# plt.axhline(y = variance/1000, color = 'r',  linestyle = '--',linewidth = 4)
sns.histplot(data)
# Out:
# mean: 6.357142857142857
# variance: 3.2295918367346945
# Std: 1.7971065179155894
# <Axes: ylabel='Count'>

# %%
data
# Out:
# array([  1,   4,   5,   7,   3,   9, 100,   5,   8, 105,   5,   8,   8,
#         -5])

# %%
threshold = 1 # threshold of std
for index, element in enumerate(data):
    z_score = (element - mean1)/std
    if np.abs(z_score) > threshold:
        print(f"index: {index}")
        print(f"Outlier: {element}")
        data[index] = data.mean()
# Out:
# index: 0
# Outlier: 1
# index: 6
# Outlier: 15
# index: 13
# Outlier: 2

# %%
data
# Out:
# array([ 1,  4,  5,  7,  3,  9, 15,  5,  8,  9,  5,  8,  8,  2])

# %%
data = sns.load_dataset('iris')

# %%
data['species'] = data.species.map({'setosa':0, 'versicolor':1, 'virginica':2})

# %%
data.species.unique()
# Out:
# array([0, 1, 2])

# %%
sns.scatterplot(data, x='sepal_length',y = 'species')
sns.regplot(data, x = 'sepal_length', y = 'species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='species'>

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]
