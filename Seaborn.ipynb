# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
x = [2,4,5,7,4,5,8,9,10]
y = [2,4,5,7,4,5,8,9,10]
sns.lineplot(x = x, y = y)
# Out:
# <Axes: >

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.lineplot(iris,x = iris.sepal_length,y = iris.sepal_width,hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
titanic = sns.load_dataset('titanic')

# %%
sns.lineplot(titanic,x = 'pclass', y = 'survived', hue = 'sex')
plt.scatter(titanic.pclass,titanic.survived)

# %%
flight = sns.load_dataset('flights')

# %%
sns.lineplot(flight, x= 'month', y = 'passengers', hue = 'year', markers='o',)
# Out:
# <Axes: xlabel='month', ylabel='passengers'>

# %%
sns.countplot(titanic,x = 'survived', hue = 'sex', )
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.barplot(titanic,x = 'embark_town', y ='fare', hue = 'alone')
plt.savefig("titanic_town_fare_alone.png")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # BOX PLOT
# ## Used for visualizing ouliers from our data

# %%
x = [20,30,50,60,80,100,1000]

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.boxplot(data = iris, x = 'species', y = 'sepal_length', hue = 'species', palette='pastel')
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.violinplot(data = iris, x = 'species', y = 'sepal_length', hue = 'species')
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.day.unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
sns.relplot(data = tips, x = "total_bill", y = 'tip', hue = 'time')

# %%
sns.relplot(data = tips, x = "day", y = 'total_bill', hue = "time")

# %%
sns.kdeplot(iris[iris['species'] == 'setosa'], x = 'sepal_length')
# Out:
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
iris['species']=iris.species.map({'setosa': 0, 'versicolor': 1, 'virginica': 2})

# %%
sns.heatmap(iris.corr(), annot= True)
# Out:
# <Axes: >

# %%
sns.pairplot(tips, hue = 'sex')

# %%
st_ad = pd.read_csv("students_adaptability_level_online_education.csv")

# %%
st_ad
# Out:
#      Gender    Age Education Level Institution Type IT Student Location  \
# 0       Boy  21-25      University   Non Government         No      Yes
# 1      Girl  21-25      University   Non Government         No      Yes
# 2      Girl  16-20         College       Government         No      Yes
# 3      Girl  11-15          School   Non Government         No      Yes
# 4      Girl  16-20          School   Non Government         No      Yes
# ...     ...    ...             ...              ...        ...      ...
# 1200   Girl  16-20         College   Non Government         No      Yes
# 1201   Girl  16-20         College   Non Government         No       No
# 1202    Boy  11-15          School   Non Government         No      Yes
# 1203   Girl  16-20         College   Non Government         No       No
# 1204   Girl  11-15          School   Non Government         No      Yes
#
#      Load-shedding Financial Condition Internet Type Network Type  \
# ...

# %% [markdown]
# # Student Adaptivity level
# 1. Plot distribution of adaptibility level.
# 2. Show distribution of gender
# 3. visualize age distribution using histograms

# %% [markdown]
# ## Relationship
# 1. Relation between education level and adaptibility level.
# 2. Compare institution type and adaptibility level.
# 3. Check if internet type affects Adaptivity level.

# %%
sns.countplot(data= st_ad, x = 'Adaptivity Level', hue = 'Gender')
# Out:
# <Axes: xlabel='Adaptivity Level', ylabel='count'>

# %%
plt.pie(st_ad['Gender'].value_counts(), labels=st_ad['Gender'].value_counts().index)
# Out:
# ([<matplotlib.patches.Wedge at 0x1fa50ac2590>,
# ...
#  [Text(-0.17278618425068662, 1.0863447585974206, 'Boy'),
#   Text(0.1727861497195785, -1.0863447640896897, 'Girl')])

# %%
sns.histplot(data=st_ad, x = 'Age')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
st_ad["Education Level"] = st_ad['Education Level'].map({"University":2,"College":1,"School":0})

# %%
st_ad["Adaptivity Level"] = st_ad['Adaptivity Level'].map({"High":2,"Moderate":1,"Low":0})

# %%
sns.lineplot(data= st_ad,x = 'Education Level', y ='Adaptivity Level', hue = 'Gender')
# Out:
# <Axes: xlabel='Education Level', ylabel='Adaptivity Level'>

# %%
sns.countplot(data= st_ad, x = 'Internet Type', hue = 'Adaptivity Level')
# Out:
# <Axes: xlabel='Internet Type', ylabel='count'>

# %%
peg = sns.load_dataset('penguins')

# %%
peg.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
heart_disease = fetch_ucirepo(id=45) 

x = heart_disease.data.features

# %%
x.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          4
# thal        2
# dtype: int64

# %%
x['num'] = heart_disease.data.targets

# %%
x
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
# 302   38    1   3       138   175    0        0      173      0      0.0
#
#      slope   ca  thal  num
# 0        3  0.0   6.0    0
# 1        2  3.0   3.0    2
# ...

# %% [markdown]
# 1. count heart disease
# 2. gender distribution
# 3. age distribution
# 4. compare gender with heart disease
# 5. compare age with heart disease
# 6. relation between age and cholestrol
# 7. compare bp with age
# 8. compare max heart rate (thalach) with age
# 9. categorical comparision of heart disease with chest pain
# 10. compare suger level with heart disease

# %%
sns.histplot(data = x, x = x['age'], bins = 20, hue = 'sex')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.barplot(data = x, x = x['num'],y = x['age'],hue = 'sex')
# Out:
# <Axes: xlabel='num', ylabel='age'>

# %%
sns.pairplot(x)

# %%
plt.figure(figsize=(12,10))
sns.heatmap(x.corr(), annot= True).set_title("Correlation map")
# Out:
# Text(0.5, 1.0, 'Correlation map')
